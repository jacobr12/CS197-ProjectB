# %%
import cg_rag

# baselines retrievers module
import cg_rag.baselines.retrievers as R
dir(R)
# Out:
# ['BM25Okapi',
#  'BM25Retriever',
#  'DenseRetriever',
#  'Embedder',
#  'List',
#  'Optional',
#  'RetrievalResult',
#  'Segment',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'np']

# %%
import inspect
print(inspect.getsource(R.DenseRetriever))
# Out:
# class DenseRetriever:
#     """Simple dense retrieval baseline using cosine similarity."""
#
#     def __init__(self, segments: List[Segment], embedder: Embedder, top_k: int = 3):
#         self.segments = segments
#         self.embedder = embedder
#         self.top_k = top_k
#
#         self.U = np.array([s.vector for s in segments])
#         norms = np.linalg.norm(self.U, axis=1, keepdims=True)
#         self.U_norm = self.U / np.maximum(norms, 1e-10)
#
#     def _get_scores(self, query: str) -> np.ndarray:
#         query_emb = self.embedder.embed([query], show_progress=False)[0]
#         query_norm = np.linalg.norm(query_emb)
#         query_normalized = query_emb / query_norm if query_norm > 1e-10 else query_emb
#         return np.dot(self.U_norm, query_normalized)
#
#     def retrieve(self, query: str, verbose: bool = False) -> RetrievalResult:
#         scores = self._get_scores(query)
#         top_indices = np.argsort(scores)[::-1][:self.top_k]
#
# ...

# %%
#importing data
from beir import util
from beir.datasets.data_loader import GenericDataLoader
data_path = util.download_and_unzip( "https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/scifact.zip","./datasets")

corpus, queries, qrels = GenericDataLoader(data_path).load(split="test")
len(corpus), len(queries)
# Out:
# /opt/miniconda3/envs/cs197-rag/lib/python3.12/site-packages/beir/util.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#   0%|          | 0/5183 [00:00<?, ?it/s]
# (5183, 300)

# %%
# exploring dataset
print("Num documents:", len(corpus))
print("Num queries:", len(queries))
print("Num qrels:", len(qrels))
import random

doc_id = random.choice(list(corpus.keys()))
doc = corpus[doc_id]

print("Doc ID:", doc_id)
print("Title:", doc.get("title", "N/A"))
print("Text:\n", doc["text"][:1000])
# Out:
# Num documents: 5183
# Num queries: 300
# Num qrels: 300
# Doc ID: 25946292
# Title: Ligand binding determines whether CD46 is internalized by clathrin-coated pits or macropinocytosis.
# Text:
# ...

# %%
#exploring what an example query asks and what counts as correct 
#chooses random query and its respective relevant documents each time
qid = random.choice(list(queries.keys()))

print("Query ID:", qid)
print("Query:", queries[qid])
print("\nRelevant docs:")

for did in qrels[qid]:
    print("Doc:", did)
    print(corpus[did]["text"][:500])
    print("-"*60)
# Out:
# Query ID: 421
# Query: Flexible molecules experience greater steric hindrance in the tumor microenviroment than rigid molecules.
#
# Relevant docs:
# Doc: 11172205
# A solid tumor is an organ composed of cancer and host cells embedded in an extracellular matrix and nourished by blood vessels. A prerequisite to understanding tumor pathophysiology is the ability to distinguish and monitor each component in dynamic studies. Standard fluorophores hamper simultaneous intravital imaging of these components. Here, we used multiphoton microscopy techniques and transgenic mice that expressed green fluorescent protein, and combined them with the use of quantum dot pre
# ------------------------------------------------------------

# %%
import numpy as np

rel_counts = [len(qrels[q]) for q in qrels]

print("Min:", min(rel_counts))
print("Max:", max(rel_counts))
print("Mean:", np.mean(rel_counts))
# Out:
# Min: 1
# Max: 5
# Mean: 1.13

# %%
import cg_rag.models.embedding as E
dir(E)
# Out:
# ['Embedder',
#  'List',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'np',
#  'torch']

# %%
# this the embedder i will use
print(inspect.getsource(E.Embedder))
# Out:
# class Embedder:
#     """Wrapper for sentence-transformers embedding models."""
#
#     def __init__(self, model_name: str = None):
#         from sentence_transformers import SentenceTransformer
#
#         # 1. Hardware Detection & Model Selection
#         if torch.cuda.is_available():
#             self.device = "cuda"
#             # High-performance, large-context embedding model
#             #default_model = 'Alibaba-NLP/gte-Qwen2-7B-instruct'
#             default_model = 'all-MiniLM-L6-v2' # use this for debugging, is super fast
#             print(f"GPU detected. Using high-fidelity embedder: {default_model}")
#         else:
#             self.device = "cpu"
#             # Lightweight, highly efficient model for CPU
#             #default_model = 'Alibaba-NLP/gte-Qwen2-1.5B-instruct'
#             default_model = 'all-MiniLM-L6-v2' # use this for debugging, is super fast
#             print(f"No GPU found. Using lightweight CPU embedder: {default_model}")
#
# ...

# %%
#creating segments stuff, trying to figure out the signature
import numpy as np
from beir import util
from beir.datasets.data_loader import GenericDataLoader
import cg_rag.baselines.retrievers as R
import cg_rag.models.embedding as E
import cg_rag.structures as S  # contains Segment, RetrievalResult, etc.
import inspect
print("Segment signature:", inspect.signature(S.Segment))
print("Segment annotations:", getattr(S.Segment, "__annotations__", None))
# Out:
# Segment signature: (text: str, vector: numpy.ndarray, start_idx: int, end_idx: int, sentences: List[str] = <factory>, internal_cost: float = 0.0) -> None
# Segment annotations: {'text': <class 'str'>, 'vector': <class 'numpy.ndarray'>, 'start_idx': <class 'int'>, 'end_idx': <class 'int'>, 'sentences': typing.List[str], 'internal_cost': <class 'float'>}

# %%
data_path = util.download_and_unzip(
    "https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/scifact.zip",
    "./datasets"
)
corpus, queries, qrels = GenericDataLoader(data_path).load(split="test")
print("corpus:", len(corpus), "queries:", len(queries))
# Out:
#   0%|          | 0/5183 [00:00<?, ?it/s]
# corpus: 5183 queries: 300

# %%
#testing out what the docs look like
doc_ids = list(corpus.keys())
doc_texts = [
    (corpus[doc_id].get("title","") + " " + corpus[doc_id].get("text","")).strip()
    for doc_id in doc_ids
]
print("Example doc:", doc_ids[0], doc_texts[0][:200])
# Out:
# Example doc: 4983 Microstructural development of human newborn cerebral white matter assessed in vivo by diffusion tensor magnetic resonance imaging. Alterations of the architecture of cerebral white matter in the deve

# %%
#embedding every document
embedder = E.Embedder() 
doc_vectors = embedder.embed(doc_texts, batch_size=64, show_progress=True)
print("doc_vectors shape:", doc_vectors.shape)
# Out:
# No GPU found. Using lightweight CPU embedder: all-MiniLM-L6-v2
# Loading embedding model: None
# Embedder ready (dim=384)
# Batches:   0%|          | 0/81 [00:00<?, ?it/s]
# doc_vectors shape: (5183, 384)

# %%
segments = []
segment_doc_ids = [] # same length as segments
for i, (doc_id, text, vec) in enumerate(zip(doc_ids, doc_texts, doc_vectors)):
    seg = S.Segment(
    text=text,
    vector=vec,
    start_idx=i,
    end_idx=i+1,
    sentences=[], # optional
    internal_cost=0.0 # optional
    )
    segments.append(seg)
    segment_doc_ids.append(doc_id)
# Map python object identity -> index, so we can recover doc_id later
seg_id_to_idx = {id(seg): i for i, seg in enumerate(segments)}
print("segments:", len(segments))
print("example:", segments[0].start_idx, segments[0].end_idx, segment_doc_ids[0])
# Out:
# segments: 5183
# example: 0 1 4983

# %%
dense = R.DenseRetriever(segments=segments, embedder=embedder, top_k=50)

# %%
qid0 = next(iter(queries.keys()))

scores_dense = dense._get_scores(queries[qid0])

print("Dense score shape:", scores_dense.shape)
print("Dense score range:", scores_dense.min(), "to", scores_dense.max())
# Out:
# Dense score shape: (5183,)
# Dense score range: -0.2132227287171643 to 0.35401319680460464

# %%
def is_hit_at_k(retrieved_doc_ids, qrel_dict):
    gold = set(qrel_dict.keys())
    return any(d in gold for d in retrieved_doc_ids)

hits = []
dense_fail_qids = []

for qid, qtext in queries.items():
    result = dense.retrieve(qtext)  # RetrievalResult

    # Convert retrieved segments to their respective doc_ids
    retrieved_doc_ids = []
    for seg in result.segments:
        idx = seg_id_to_idx[id(seg)]
        retrieved_doc_ids.append(segment_doc_ids[idx])

    hit = is_hit_at_k(retrieved_doc_ids, qrels.get(qid, {}))
    hits.append(hit)
    if not hit:
        dense_fail_qids.append(qid)

print(f"Dense hit@10: {sum(hits)}/{len(hits)} = {sum(hits)/len(hits):.3f}")
print("Dense failures:", len(dense_fail_qids))
dense_fail_qids[:20]
# Out:
# Dense hit@10: 270/300 = 0.900
# Dense failures: 30
# ['48',
#  '128',
#  '132',
#  '198',
#  '303',
#  '312',
#  '314',
#  '421',
#  '437',
#  '502',
#  '517',
#  '560',
#  '660',
#  '690',
#  '785',
#  '820',
#  '821',
#  '831',
#  '834',
#  '975']

# %%
# --- Week 6: Dense pricing retrieval experiment ---
def rank_norm(x):
    order = np.argsort(x)
    ranks = np.empty_like(order, dtype=float)
    ranks[order] = np.arange(len(x), dtype=float)
    return ranks / max(len(x) - 1, 1)
def dense_pricing_indices(query, lam_d=1.0, cost=1.0, k=10):
    d = dense._get_scores(query)
    dN = rank_norm(d)

    rc = cost - lam_d * dN

    selected = np.where(rc < 0)[0]

    if len(selected) == 0:
        selected = np.argsort(dN)[::-1][:k]
    else:
        selected = selected[np.argsort(dN[selected])[::-1]]

    return selected


def eval_dense_pricing(k=10):
    hits = 0

    for qid, qtext in queries.items():
        idx = dense_pricing_indices(qtext, lam_d=1.0, k=k)

        retrieved_doc_ids = [segment_doc_ids[i] for i in idx[:k]]

        if is_hit_at_k(retrieved_doc_ids, qrels.get(qid, {})):
            hits += 1

    return hits / len(queries)


print("Dense pricing hit@10:", eval_dense_pricing())
# Out:
# Dense pricing hit@10: 0.7933333333333333

# %%
import pandas as pd

rows = []

for qid in dense_fail_qids:
    rows.append({
        "qid": qid,
        "query": queries[qid],
        "label": "",
        "notes": ""
    })

dense_fail_df = pd.DataFrame(rows)
dense_fail_df.head(10)
# Out:
#    qid                                              query label notes
# 0   48  A total of 1,000 people in the UK are asymptom...
# 1  128  Arterioles have a larger lumen diameter than v...
# 2  132           Aspirin inhibits the production of PGE2.
# 3  198                       CCL19 is absent within dLNs.
# 4  303  DMRT1 is a sex-determining gene that is epigen...
# 5  312  De novo assembly of sequence data has more spe...
# 6  314  Deamination of cytidine to uridine on the minu...
# 7  421  Flexible molecules experience greater steric h...
# 8  437  Functional consequences of genomic alterations...
# 9  502  Healthcare delivery efficiency in crowded deli...

# %%
import pandas as pd

def dense_failure_row(qid, k=5):
    qtext = queries[qid]
    gold_ids = list(qrels.get(qid, {}).keys())

    result = dense.retrieve(qtext)
    top_ids = [
        segment_doc_ids[seg_id_to_idx[id(s)]]
        for s in result.segments[:k]
    ]

    # short snippets so it’s readable
    top_snips = []
    for doc_id in top_ids:
        txt = (corpus[doc_id].get("title","") + " " + corpus[doc_id].get("text",""))[:300]
        top_snips.append({"doc_id": doc_id, "snippet": txt})

    gold_snips = []
    for doc_id in gold_ids[:3]:
        txt = (corpus[doc_id].get("title","") + " " + corpus[doc_id].get("text",""))[:300]
        gold_snips.append({"doc_id": doc_id, "snippet": txt})

    return {
        "qid": qid,
        "query": qtext,
        "gold_ids": gold_ids,
        "gold_preview": gold_snips,
        "dense_top_ids": top_ids,
        "dense_top_preview": top_snips,
    }

dense_fail_payload = [dense_failure_row(qid, k=5) for qid in dense_fail_qids]
df = pd.DataFrame(dense_fail_payload)
df.head()
df.to_json("dense_fail_payload.jsonl", orient="records", lines=True)

# %%
def inspect_dense_fail(qid, k=5):
    qtext = queries[qid]
    gold_ids = list(qrels.get(qid, {}).keys())

    result = dense.retrieve(qtext)
    retrieved = [
        segment_doc_ids[seg_id_to_idx[id(s)]]
        for s in result.segments[:k]
    ]

    print("="*70)
    print("QID:", qid)
    print("QUERY:", qtext)
    print("GOLD DOC IDS:", gold_ids[:5])

    print("\nTOP DENSE RESULTS:")
    for i, doc_id in enumerate(retrieved, 1):
        text = (
            corpus[doc_id].get("title","") +
            " " +
            corpus[doc_id].get("text","")
        )[:250]
        print(f"{i}. {doc_id} | {text}...")

    print("="*70)

# %%
for qid in dense_fail_qids:
    inspect_dense_fail(qid)
# Out:
# ...
# QID: 48
# QUERY: A total of 1,000 people in the UK are asymptomatic carriers of vCJD infection.
# GOLD DOC IDS: ['13734012']
#
# TOP DENSE RESULTS:
# 1. 18617259 | Research Letters We report a case of preclinical variant Creutzfeldt-Jakob disease (vCJD) in a patient who died from a non-neurological disorder 5 years after receiving a blood transfusion from a donor who subsequently developed vCJD. Protease-resist...
# 2. 11349166 | Lack of evidence of transfusion transmission of Creutzfeldt-Jakob disease in a US surveillance study. BACKGROUND Since 2004, several reported transfusion transmissions of variant Creutzfeldt-Jakob disease (vCJD) in the United Kingdom have reawakened ...
# 3. 24512064 | HTLV-I/II associated disease in England and Wales, 1993-7: retrospective review of serology requests. Apart from HIV two exogenous retroviruses (human T cell leukaemia viruses type I (HTLV-I) and type II (HTLV-II)) infect humans. HTLV-I infection is ...
# ...

# %%
rows = []

for qid in dense_fail_qids:
    qtext = queries[qid]
    gold_ids = list(qrels[qid].keys())

    result = dense.retrieve(qtext)
    retrieved_ids = [
        segment_doc_ids[seg_id_to_idx[id(s)]]
        for s in result.segments[:5]
    ]

    rows.append({
        "qid": qid,
        "query": qtext,
        "gold_ids": gold_ids,
        "top_retrieved_ids": retrieved_ids
    })
import pandas as pd

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

fail_table = pd.DataFrame(rows)
fail_table
# Out:
#      qid  \
# 0     48
# 1    128
# 2    132
# 3    198
# 4    303
# 5    312
# 6    314
# 7    421
# 8    437
# 9    502
# 10   517
# 11   560
# 12   660
# 13   690
# 14   785
# 15   820
# 16   821
# 17   831
# 18   834
# 19   975
# 20  1110
# 21  1175
# 22  1179
# 23  1199
# 24  1200
# 25  1213
# 26  1226
# 27  1332
# 28  1362
# 29  1363
#
#                                                                                                                                              query  \
# 0                                                                   A total of 1,000 people in the UK are asymptomatic carriers of vCJD infection.
# 1                                                                                            Arterioles have a larger lumen diameter than venules.
# 2                                                                                                         Aspirin inhibits the production of PGE2.
# ...

# %%
label_map = {
  "Paraphrase": {
    "13","128","239","384","421","475","508","619","623","644","820","821","870","887","975","1110","1199","1213",
    "1362","1363","1368"
  },
  "Entities": {
    "48","70","132","198","303","544","554","560","715","716","834","1024","1041","1175","1179","1180","1200",
    "1226","1272","1316"
  },
  "Keyword overload": {
    "415","431","437","502","527","587","690","768","775","830","831","1280","1332"
  },
  "Rare terms": {
    "294","312","314","517","660","743","785","1049"
  }
}

# %%
k = 10

def is_hit_at_k(retrieved_doc_ids, qrel_dict):
    gold = set(qrel_dict.keys())
    return any(d in gold for d in retrieved_doc_ids)

hits = []
dense_fail_qids = []
qid_categories_dense = {}

for qid, qtext in queries.items():
    result = dense.retrieve(qtext)  # RetrievalResult

    # convert retrieved segments todoc_ids
    retrieved_doc_ids = []
    for seg in result.segments[:k]:
        idx = seg_id_to_idx[id(seg)]
        retrieved_doc_ids.append(segment_doc_ids[idx])

    hit = is_hit_at_k(retrieved_doc_ids, qrels.get(qid, {}))
    hits.append(hit)

    if not hit:
        dense_fail_qids.append(qid)
        qid_categories_dense[qid] = {
            "dense": False,
            "query": qtext,
            "Failure Category": None  # fill manually via label_map
        }
    else:
        qid_categories_dense[qid] = {
            "dense": True,
            "query": qtext,
            "Failure Category": "not a failure"
        }

print(f"Dense hit@{k}: {sum(hits)}/{len(hits)} = {sum(hits)/len(hits):.3f}")
print("Dense failures:", len(dense_fail_qids))
dense_fail_qids
# Out:
# Dense hit@10: 238/300 = 0.793
# Dense failures: 62
# ['13',
#  '48',
#  '70',
#  '128',
#  '132',
#  '198',
#  '239',
#  '294',
#  '303',
#  '312',
#  '314',
#  '384',
#  '415',
#  '421',
#  '431',
#  '437',
#  '475',
#  '502',
#  '508',
#  '517',
#  '527',
#  '544',
#  '554',
#  '560',
#  '587',
#  '619',
#  '623',
#  '644',
#  '660',
#  '690',
#  '715',
#  '716',
#  '743',
#  '768',
#  '775',
#  '785',
#  '820',
#  '821',
#  '830',
#  '831',
#  '834',
#  '870',
#  '887',
#  '975',
#  '1024',
#  '1041',
#  '1049',
#  '1110',
#  '1175',
#  '1179',
#  '1180',
#  '1199',
#  '1200',
#  '1213',
#  '1226',
#  '1272',
#  '1280',
#  '1316',
#  '1332',
#  '1362',
#  '1363',
#  '1368']

# %%
for qid in qid_categories_dense:
    if not qid_categories_dense[qid]["dense"]:  # only label failures
        for label, qids in label_map.items():
            if qid in qids:
                qid_categories_dense[qid]["Failure Category"] = label
                break

# any failures not in label_map become "Unlabeled"
for qid in qid_categories_dense:
    if (qid_categories_dense[qid]["dense"] == False) and (qid_categories_dense[qid]["Failure Category"] is None):
        qid_categories_dense[qid]["Failure Category"] = "Unlabeled"

# %%
qid_categories_dense
# Out:
# {'1': {'dense': True,
#   'query': '0-dimensional biomaterials show inductive properties.',
#   'Failure Category': 'not a failure'},
#  '3': {'dense': True,
#   'query': '1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.',
#   'Failure Category': 'not a failure'},
#  '5': {'dense': True,
#   'query': '1/2000 in UK have abnormal PrP positivity.',
#   'Failure Category': 'not a failure'},
#  '13': {'dense': False,
#   'query': '5% of perinatal mortality is due to low birth weight.',
#   'Failure Category': 'Paraphrase'},
#  '36': {'dense': True,
#   'query': 'A deficiency of vitamin B12 increases blood levels of homocysteine.',
#   'Failure Category': 'not a failure'},
#  '42': {'dense': True,
#   'query': 'A high microerythrocyte count raises vulnerability to severe anemia in homozygous alpha (+)- thalassemia trait subjects.',
#   'Failure Category': 'not a failure'},
# ...

# %% [markdown]
# SPARSE RETRIEVAL

# %%
sparse_label_map = {
    "Paraphrase": {
        1, 13, 132, 238, 239, 384, 623, 800, 870, 913, 914,
        975, 1049, 1088, 1110, 1191, 1199, 1213, 1226, 1241,
        1278, 1279, 1316, 1332, 1368
    },

    "Entities": {
        431, 437, 517, 535, 544, 577, 690, 715, 716, 768,
        775, 830, 831, 1200, 1280, 1281, 1382
    },

    "Keyword overload": {
        502, 820, 821, 887, 1196, 1197, 783, 1395
    },

    "Rare terms": {
        1140, 1221
    }
}

# %%
from rank_bm25 import BM25Okapi
import re
import numpy as np
import pandas as pd
# --- Week 6: Build BM25 scoring for hybrid pricing ---
tokenized_docs = [doc.split() for doc in doc_texts]

bm25 = BM25Okapi(tokenized_docs)

scores_bm25 = bm25.get_scores(queries[qid0].split())

print("BM25 score shape:", scores_bm25.shape)
print("BM25 score range:", scores_bm25.min(), "to", scores_bm25.max())
      
# ----------------------------
# 0) Ensure int qids (matches label sets like {13, 48, ...})
# ----------------------------
queries_int = {int(k): v for k, v in queries.items()}
qrels_int   = {int(k): v for k, v in qrels.items()}

# ----------------------------
# 1) Tokenizer
# ----------------------------
token_pat = re.compile(r"\w+")
def tokenize(text: str):
    return token_pat.findall(text.lower())

# ----------------------------
# 2) Flatten corpus into aligned lists
# ----------------------------
doc_ids = list(corpus.keys())
doc_texts = [
    (corpus[doc_id].get("title", "") + " " + corpus[doc_id].get("text", "")).strip()
    for doc_id in doc_ids
]
tokenized_docs = [tokenize(text) for text in doc_texts]

# ----------------------------
# 3) Build BM25 index
# ----------------------------
bm25 = BM25Okapi(tokenized_docs)

# ----------------------------
# 4) Retrieval function
# ----------------------------
def bm25_retrieve(query_text: str, k: int = 10):
    q_tokens = tokenize(query_text)
    scores = bm25.get_scores(q_tokens)
    top_idx = np.argsort(scores)[::-1][:k]
    return [(doc_ids[i], float(scores[i])) for i in top_idx]

# ----------------------------
# 5) Run BM25 over all queries
# ----------------------------
k = 50
bm25_results = {qid: bm25_retrieve(qtext, k=k) for qid, qtext in queries_int.items()}

# ----------------------------
# 6) Success definition (same idea as dense)
# ----------------------------
def is_hit_at_k(retrieved_doc_ids, qrel_dict):
    gold = set(qrel_dict.keys())
    return any(d in gold for d in retrieved_doc_ids)

# ----------------------------
# 7) Evaluate + build qid_categories_sparse (BM25 analog of dense)
# ----------------------------
hits = []
bm25_fail_qids = []
qid_categories_sparse = {}  # qid -> {bm25, query, Failure Category}

for qid, qtext in queries_int.items():
    retrieved_doc_ids = [doc_id for (doc_id, _) in bm25_results[qid]]
    hit = is_hit_at_k(retrieved_doc_ids, qrels_int.get(qid, {}))
    hits.append(hit)

    if not hit:
        bm25_fail_qids.append(qid)
        qid_categories_sparse[qid] = {
            "bm25": False,
            "query": qtext,
            "Failure Category": None,
        }
    else:
        qid_categories_sparse[qid] = {
            "bm25": True,
            "query": qtext,
            "Failure Category": "not a failure",
        }

print(f"BM25 hit@{k}: {sum(hits)}/{len(hits)} = {sum(hits)/len(hits):.3f}")
print("BM25 failures:", len(bm25_fail_qids))

# ----------------------------
# 8) Convenience: failure inspection dict
# ----------------------------
not_hit_dict = {}
for qid in bm25_fail_qids:
    retrieved_doc_ids = [doc_id for (doc_id, _) in bm25_results[qid]]
    not_hit_dict[qid] = {
        "retrieved": retrieved_doc_ids,
        "true_relevant": qrels_int.get(qid, {}),
    }

# ----------------------------
# 9) Apply sparse_label_map to ONLY the failures
# ----------------------------
for label, qid_set in sparse_label_map.items():
    for qid in qid_set:
        if qid in qid_categories_sparse and qid_categories_sparse[qid]["bm25"] is False:
            qid_categories_sparse[qid]["Failure Category"] = label

# any remaining BM25 failures not labeled
for qid in qid_categories_sparse:
    if (qid_categories_sparse[qid]["bm25"] is False) and (qid_categories_sparse[qid]["Failure Category"] is None):
        qid_categories_sparse[qid]["Failure Category"] = "Unlabeled"

# ----------------------------
# 10) Make DataFrames AFTER labeling (this is the key)
# ----------------------------
bm25_df = pd.DataFrame([{"qid": qid, **qid_categories_sparse[qid]} for qid in qid_categories_sparse]).sort_values("qid")
fail_df_bm25 = bm25_df[bm25_df["bm25"] == False].copy()


qid_categories_sparse = {
    int(k): v for k, v in qid_categories_sparse.items()
}
for qid in qid_categories_sparse:
    if not qid_categories_sparse[qid]["bm25"]:
        for label, qids in sparse_label_map.items():
            if qid in qids:
                qid_categories_sparse[qid]["Failure Category"] = label
                break

# Fill remaining
for qid in qid_categories_sparse:
    if (qid_categories_sparse[qid]["bm25"] == False and
        qid_categories_sparse[qid]["Failure Category"] is None):
        qid_categories_sparse[qid]["Failure Category"] = "Unlabeled"
display(bm25_df.head())
display(fail_df_bm25.head())
display(fail_df_bm25["Failure Category"].value_counts())
# Out:
# BM25 score shape: (5183,)
# BM25 score range: 0.0 to 9.49137878772776
# BM25 hit@50: 262/300 = 0.873
# BM25 failures: 38
#    qid   bm25  \
# 0    1  False
# 1    3   True
# 2    5   True
# 3   13   True
# 4   36   True
#
#                                                                                                                                                   query  \
# 0                                                                                                 0-dimensional biomaterials show inductive properties.
# 1  1,000 genomes project enables mapping of genetic sequence variation consisting of rare variants with larger penetrance effects than common variants.
# 2                                                                                                            1/2000 in UK have abnormal PrP positivity.
# 3                                                                                                 5% of perinatal mortality is due to low birth weight.
# ...

# %%
### week 6
from rank_bm25 import BM25Okapi
import re
import numpy as np

token_pat = re.compile(r"\w+")
def tokenize(text: str):
    return token_pat.findall(text.lower())

# Build doc_texts in the SAME order as segments/segment_doc_ids
doc_texts_aligned = [
    (corpus[doc_id].get("title","") + " " + corpus[doc_id].get("text","")).strip()
    for doc_id in segment_doc_ids
]
bm25 = BM25Okapi([tokenize(t) for t in doc_texts_aligned])

# sanity check alignment
qid0 = next(iter(queries.keys()))
b = bm25.get_scores(tokenize(queries[qid0]))
print(b.shape, b.min(), b.max())
# Out:
# (5183,) 0.0 10.173663486906072

# %%
# --- Week 6: Hybrid pricing experiment ---

def hybrid_pricing_indices(query, lam_d=1.0, lam_s=1.0, cost=1.0, k=10):
    d = dense._get_scores(query)
    b = bm25.get_scores(query.split())

    dN = rank_norm(d)
    bN = rank_norm(b)

    rc = cost - lam_d*dN - lam_s*bN

    selected = np.where(rc < 0)[0]

    fused = lam_d*dN + lam_s*bN

    if len(selected) == 0:
        selected = np.argsort(fused)[::-1][:k]
    else:
        selected = selected[np.argsort(fused[selected])[::-1]]

    return selected


def eval_hybrid_pricing(k=10):
    hits = 0

    for qid, qtext in queries.items():
        idx = hybrid_pricing_indices(qtext, lam_d=1.0, lam_s=1.0, k=k)

        retrieved_doc_ids = [segment_doc_ids[i] for i in idx[:k]]

        if is_hit_at_k(retrieved_doc_ids, qrels.get(qid, {})):
            hits += 1

    return hits / len(queries)


print("Hybrid pricing hit@10:", eval_hybrid_pricing())
# Out:
# Hybrid pricing hit@10: 0.69

# %%
fail_df_bm25

# %%
import pandas as pd


fail_df_bm25["Failure Category"].value_counts()

# %%
# Dense dataframe
dense_df = pd.DataFrame([
    {
        "qid": qid,
        "dense": v["dense"],
        "dense_category": v["Failure Category"],
        "query": v["query"]
    }
    for qid, v in qid_categories_dense.items()
])

# BM25 dataframe
bm25_df = pd.DataFrame([
    {
        "qid": qid,
        "bm25": v["bm25"],
        "bm25_category": v["Failure Category"],
        "query": v["query"]
    }
    for qid, v in qid_categories_sparse.items()
])

# %%
dense_df["qid"] = dense_df["qid"].astype(str)
bm25_df["qid"]  = bm25_df["qid"].astype(str)

# (optional but recommended) normalize query whitespace too
dense_df["query"] = dense_df["query"].astype(str).str.strip()
bm25_df["query"]  = bm25_df["query"].astype(str).str.strip()

merged_df = dense_df.merge(bm25_df, on=["qid", "query"], how="inner")
merged_df.head()

merged_df = dense_df.merge(
    bm25_df,
    on=["qid", "query"],
    how="inner"
)

merged_df.head()

# %%
dense_failures = merged_df[merged_df["dense"] == False]

dense_failures["dense_category"].value_counts()

# %%
bm25_failures = merged_df[merged_df["bm25"] == False]

bm25_failures["bm25_category"].value_counts()

# %%
dense_failures = merged_df[merged_df["dense"] == False]

dense_failures["dense_category"].value_counts().plot(
    kind="bar",
    title="Dense Retrieval Failure Categories",
    figsize=(7,5)
)

# %%
unlabeled = bm25_counts["Unlabeled"]

# categories that will receive redistributed mass
labeled_cats = ["Paraphrase", "Entities", "Keyword overload", "Rare terms"]

total_labeled = sum(bm25_counts[c] for c in labeled_cats)

redistributed_counts = {}

for c in labeled_cats:
    redistributed_counts[c] = bm25_counts[c] + unlabeled * (bm25_counts[c] / total_labeled)

# %%
def outcome(row):
    if not row["dense"] and not row["bm25"]:
        return "Both Fail"
    if not row["dense"] and row["bm25"]:
        return "Dense Only Fail"
    if row["dense"] and not row["bm25"]:
        return "BM25 Only Fail"
    return "Both Succeed"

merged_df["outcome"] = merged_df.apply(outcome, axis=1)

merged_df["outcome"].value_counts()

# %%
merged_df["outcome"].value_counts().plot(
    kind="bar",
    title="Dense vs BM25 Outcomes",
    figsize=(7,5)
)

# %%
confusion = pd.crosstab(
    dense_failures["dense_category"],
    dense_failures["bm25_category"],
    normalize="index"
)

confusion

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.imshow(confusion, aspect="auto")

plt.xticks(range(len(confusion.columns)), confusion.columns, rotation=45)
plt.yticks(range(len(confusion.index)), confusion.index)

plt.colorbar(label="Proportion")
plt.title("Dense vs BM25 Failure Category Alignment")

plt.show()
confusion_filtered = confusion.drop(
    index="unlabeled",
    columns="unlabeled",
    errors="ignore"
)
plt.figure(figsize=(8,6))
plt.imshow(confusion_filtered, aspect="auto")

plt.xticks(
    range(len(confusion_filtered.columns)),
    confusion_filtered.columns,
    rotation=45
)
plt.yticks(
    range(len(confusion_filtered.index)),
    confusion_filtered.index
)

plt.colorbar(label="Proportion")
plt.title("Dense vs BM25 Failure Category Alignment")
plt.show()

# %%
#these are dense weaknesses
dense_only = merged_df[
    (merged_df["dense"] == False) &
    (merged_df["bm25"] == True)
]

dense_only["dense_category"].value_counts()

# %%
#these are sparse weaknesses
bm25_only = merged_df[
    (merged_df["dense"] == True) &
    (merged_df["bm25"] == False)
]

bm25_only["bm25_category"].value_counts()

# %%
both_fail = merged_df[
    (merged_df["dense"] == False) &
    (merged_df["bm25"] == False)
]

both_fail[["qid", "query", "dense_category", "bm25_category"]].head()
both_fail["dense_category"].value_counts()

# %%
import numpy as np
from typing import Dict, Any, List, Callable, Union, Tuple

# ------------------------------------------------------------
# Helpers
# ------------------------------------------------------------

def minmax_norm(x: np.ndarray, eps: float = 1e-12) -> np.ndarray:
    """
    Min-max normalize an array to [0, 1].
    If all values are identical (or nearly), return all zeros.
    """
    x = x.astype(float)
    lo, hi = float(np.min(x)), float(np.max(x))
    if hi - lo < eps:
        return np.zeros_like(x)
    return (x - lo) / (hi - lo)


def iter_queries_with_ids(
    queries: Union[Dict[str, str], List[str], List[Dict[str, Any]]]
) -> List[Tuple[str, str]]:
    """
    Returns a list of (qid, query_text).

    Supports:
      - BEIR style: queries = {qid: query_text, ...}
      - list[str]
      - list[{"qid": ..., "query": ...}, ...]  (or {"query": ...} -> qid becomes index)
    """
    if isinstance(queries, dict):
        # BEIR: dict[qid] = query_text
        return [(qid, qtext) for qid, qtext in queries.items()]

    if isinstance(queries, list):
        if len(queries) == 0:
            return []
        if isinstance(queries[0], str):
            return [(str(i), q) for i, q in enumerate(queries)]
        if isinstance(queries[0], dict) and "query" in queries[0]:
            out = []
            for i, row in enumerate(queries):
                qid = str(row.get("qid", i))
                out.append((qid, row["query"]))
            return out

    raise ValueError("Unsupported queries format. Use dict[qid->text], list[str], or list[dict with 'query'].")


def relevant_doc_ids_for_qid(
    qrels: Dict[str, Dict[str, int]],
    qid: str,
    min_rel: int = 1
) -> set:
    """
    BEIR qrels structure: qrels[qid] is a dict of {doc_id: relevance_int}.
    We consider doc relevant if relevance >= min_rel.
    """
    if qid not in qrels:
        return set()
    return {doc_id for doc_id, rel in qrels[qid].items() if rel >= min_rel}


# ------------------------------------------------------------
# Core: run dense + BM25, normalize per query, threshold BOTH, and check success
# ------------------------------------------------------------

def threshold_scan_with_relevance(
    queries: Union[Dict[str, str], List[str], List[Dict[str, Any]]],
    qrels: Dict[str, Dict[str, int]],
    dense_retriever,                     # your DenseRetriever
    bm25,                                # BM25Okapi
    doc_ids: List[str],                  # aligned to both retrievers
    tokenize: Callable[[str], List[str]],
    thresholds: List[float],             # e.g., [0.70, 0.75, 0.80, 0.85, 0.90]
    min_rel: int = 1,                    # relevance cutoff for "success"
    top_k_per_query: int = 100,          # after thresholding, cap how many you keep (for logging/storage)
    verbose: bool = True
) -> Dict[float, Dict[str, Any]]:
    """
    For each query:
      1) compute dense raw scores over ALL docs
      2) compute BM25 raw scores over ALL docs
      3) min-max normalize each to [0,1] PER QUERY
      4) for each threshold t: keep docs where (dense_norm >= t) AND (bm25_norm >= t)
      5) sort kept docs by avg_norm = 0.5*dense_norm + 0.5*bm25_norm (just for ranking/logging)
      6) SUCCESS if any kept doc is relevant per qrels

    Returns:
      dict keyed by threshold with:
        - summary stats (success rate, avg kept, etc.)
        - per-query details including success boolean and first relevant rank (within kept list)
    """

    # Prepare query list as (qid, query_text)
    qid_query_pairs = iter_queries_with_ids(queries)
    doc_ids = list(doc_ids)
    N = len(doc_ids)

    # Precompute normalized scores per query (so threshold loop is cheap)
    dense_norm_all: Dict[str, np.ndarray] = {}
    bm25_norm_all: Dict[str, np.ndarray] = {}

    for qid, qtext in qid_query_pairs:
        # Dense raw scores (cosine sims)
        dense_raw = dense_retriever._get_scores(qtext)  # shape (N,)
        if len(dense_raw) != N:
            raise ValueError(f"[qid={qid}] Dense score length {len(dense_raw)} != doc_ids length {N}")

        # BM25 raw scores
        bm25_raw = bm25.get_scores(tokenize(qtext))     # shape (N,)
        if len(bm25_raw) != N:
            raise ValueError(f"[qid={qid}] BM25 score length {len(bm25_raw)} != doc_ids length {N}")

        # Normalize to [0,1] per query
        dense_norm_all[qid] = minmax_norm(np.asarray(dense_raw))
        bm25_norm_all[qid]  = minmax_norm(np.asarray(bm25_raw))

    out: Dict[float, Dict[str, Any]] = {}

    # ------------------------------------------------------------
    # Threshold scan loop
    # ------------------------------------------------------------
    for t in thresholds:
        per_query_rows = []
        total_kept = 0
        num_success = 0

        for qid, qtext in qid_query_pairs:
            dnorm = dense_norm_all[qid]
            bnorm = bm25_norm_all[qid]

            # Keep docs where BOTH >= threshold
            keep_mask = (dnorm >= t) & (bnorm >= t)
            keep_idx = np.where(keep_mask)[0]

            # Rank within kept docs (for convenience / evaluation rank)
            if keep_idx.size > 0:
                avg_norm = 0.5 * dnorm + 0.5 * bnorm
                keep_idx = keep_idx[np.argsort(avg_norm[keep_idx])[::-1]]

            # Cap list length (doesn't affect "did we keep any relevant doc" if your cap is large enough)
            keep_idx = keep_idx[:top_k_per_query]

            kept_doc_ids = [doc_ids[i] for i in keep_idx]

            # Determine if we successfully returned at least one relevant doc
            rel_set = relevant_doc_ids_for_qid(qrels, qid, min_rel=min_rel)
            hit_positions = [j for j, doc_id in enumerate(kept_doc_ids) if doc_id in rel_set]

            success = len(hit_positions) > 0
            first_rel_rank = (hit_positions[0] + 1) if success else None  # 1-based rank within kept list

            total_kept += len(kept_doc_ids)
            num_success += int(success)

            per_query_rows.append({
                "qid": qid,
                "query": qtext,
                "threshold": float(t),
                "kept_count": int(len(kept_doc_ids)),
                "success": bool(success),
                "first_relevant_rank_in_kept": first_rel_rank,
                "kept_doc_ids": kept_doc_ids,
                # Uncomment if you want to inspect normalized scores too:
                # "kept_dense_norm": [float(dnorm[i]) for i in keep_idx],
                # "kept_bm25_norm":  [float(bnorm[i]) for i in keep_idx],
            })

        num_q = len(qid_query_pairs)
        success_rate = num_success / max(num_q, 1)
        avg_kept = total_kept / max(num_q, 1)

        out[t] = {
            "threshold": float(t),
            "num_queries": int(num_q),
            "num_success": int(num_success),
            "success_rate": float(success_rate),
            "total_kept_docs": int(total_kept),
            "avg_kept_docs_per_query": float(avg_kept),
            "per_query": per_query_rows,
        }

        # Print summary each iteration
        if verbose:
            print(
                f"[t={t:.2f}] success={num_success}/{num_q} ({success_rate:.3f}) | "
                f"avg_kept={avg_kept:.2f} | total_kept={total_kept}"
            )

    return out

# %%
# BEIR gives:
#   queries: dict[qid -> query_text]
#   qrels:  dict[qid -> dict[doc_id -> relevance]]
# and you already have dense_retriever, bm25, doc_ids, tokenize

thresholds = [0.65, 0.6, 0.55, 0.5, 0.70, 0.75, 0.80, 0.85, 0.90]

scan = threshold_scan_with_relevance(
    queries=queries,
    qrels=qrels,
    dense_retriever=dense,
    bm25=bm25,
    doc_ids=doc_ids,
    tokenize=tokenize,
    thresholds=thresholds,
    min_rel=1,
    top_k_per_query=200,   # set high so you don't accidentally cut off relevant docs
    verbose=True
)

# Look at the best threshold by success_rate
best_t = max(scan.keys(), key=lambda t: scan[t]["success_rate"])
best_t, scan[best_t]["success_rate"]

# %%
import matplotlib.pyplot as plt

thresholds = sorted(scan.keys())
success_rates = [scan[t]["success_rate"] for t in thresholds]

plt.figure()
plt.plot(thresholds, success_rates, marker="o")
plt.xlabel("Threshold (dense_norm ≥ t AND bm25_norm ≥ t)")
plt.ylabel("Success rate")
plt.title("Success rate vs threshold (dense ∧ BM25 agreement)")
plt.ylim(0, 1)
plt.show()

# %%
avg_kept = [scan[t]["avg_kept_docs_per_query"] for t in thresholds]

plt.figure()
plt.plot(thresholds, avg_kept, marker="o")
plt.xlabel("Threshold")
plt.ylabel("Average # docs kept per query")
plt.title("Candidate set size vs threshold")
plt.show()

# %%
plt.figure()
plt.plot(avg_kept, success_rates, marker="o")
plt.xlabel("Average # docs kept per query")
plt.ylabel("Success rate")
plt.title("Success vs candidate set size (agreement gate)")

for t, x, y in zip(thresholds, avg_kept, success_rates):
    plt.annotate(f"t={t:.2f}", (x, y), xytext=(6, 6), textcoords="offset points")

plt.ylim(0, 1)
plt.show()

# %%
import matplotlib.pyplot as plt

# ---- Baseline curves from your screenshot ----
bm25_hit_by_k = {
    1: 0.523,
    3: 0.693,
    5: 0.757,
    10: 0.797,
    15: 0.827,
    20: 0.850,
    30: 0.860,
    50: 0.873,
}

dense_hit_by_k = {
    1: 0.503,
    3: 0.683,
    5: 0.753,
    10: 0.793,
    15: 0.833,
    20: 0.847,
    30: 0.873,
    50: 0.900,
}

# ---- Hybrid scan points (from threshold_scan_with_relevance output `scan`) ----
thresholds = sorted(scan.keys())
hybrid_success = [scan[t]["success_rate"] for t in thresholds]
hybrid_avg_kept = [scan[t]["avg_kept_docs_per_query"] for t in thresholds]

# ---- Prepare baseline series ----
dense_ks = sorted(dense_hit_by_k.keys())
dense_hits = [dense_hit_by_k[k] for k in dense_ks]

bm25_ks = sorted(bm25_hit_by_k.keys())
bm25_hits = [bm25_hit_by_k[k] for k in bm25_ks]

# ---- Plot overlay ----
plt.figure()

# Baselines
plt.plot(dense_ks, dense_hits, marker="o", label="Dense hit@k")
plt.plot(bm25_ks, bm25_hits, marker="o", label="BM25 hit@k")

# Hybrid gate
plt.plot(hybrid_avg_kept, hybrid_success, marker="o", label="Dense ∧ BM25 gate")

# Annotate hybrid thresholds
for t, x, y in zip(thresholds, hybrid_avg_kept, hybrid_success):
    plt.annotate(f"t={t:.2f}", (x, y), xytext=(5, 5), textcoords="offset points")

# 🔥 ZOOM HERE
plt.xlim(0, 50)
plt.ylim(0.45, 1)

plt.xlabel("Candidate set size")
plt.ylabel("Success rate")
plt.title("Zoomed-in: Success vs Candidate Set Size (k ≤ 15)")
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd

# ---------- helpers (same as before) ----------
def minmax_norm(x, eps=1e-12):
    x = x.astype(float)
    lo, hi = float(np.min(x)), float(np.max(x))
    if hi - lo < eps:
        return np.zeros_like(x)
    return (x - lo) / (hi - lo)

def rank_norm(x):
    order = np.argsort(x)
    ranks = np.empty_like(order, dtype=float)
    ranks[order] = np.arange(len(x), dtype=float)
    return ranks / max(len(x) - 1, 1)

def zsigmoid_norm(x, eps=1e-12):
    mu = np.mean(x)
    sd = np.std(x)
    if sd < eps:
        return np.zeros_like(x, dtype=float)
    z = (x - mu) / sd
    return 1.0 / (1.0 + np.exp(-z))

def normalize_scores(x, method: str):
    if method == "minmax":
        return minmax_norm(x)
    if method == "rank":
        return rank_norm(x)
    if method == "zsigmoid":
        return zsigmoid_norm(x)
    raise ValueError(method)

def fuse_scores(d_norm, b_norm, method: str, alpha: float):
    if method == "wsum":
        return alpha * d_norm + (1 - alpha) * b_norm
    if method == "wprod":
        eps = 1e-12
        return (np.maximum(d_norm, eps) ** alpha) * (np.maximum(b_norm, eps) ** (1 - alpha))
    raise ValueError(method)

def hit_at_k(topk_doc_ids, qrel_dict):
    gold = set(qrel_dict.keys())
    return any(d in gold for d in topk_doc_ids)

def mrr_at_k(topk_doc_ids, qrel_dict):
    gold = set(qrel_dict.keys())
    for i, d in enumerate(topk_doc_ids):
        if d in gold:
            return 1.0 / (i + 1)
    return 0.0


# ---------- FAST sweep ----------
def fast_sweep_fusion(
    queries_int,
    qrels_int,
    dense,
    bm25,
    doc_ids,
    tokenize,
    norm_methods=("minmax", "rank", "zsigmoid"),
    fusion_methods=("wsum", "wprod"),
    alphas=(0.0, 0.5, 1.0),
    ks=(1, 3, 5, 10, 20, 50),
    pre_topM: int = 200,   # only keep top 200 candidates per query (huge speedup)
):
    """
    Runs in two phases:
      1) Precompute dense_raw and bm25_raw ONCE per query and restrict to union of topM from each
      2) Sweep norm/fusion/alpha/k over only those candidates (fast)
    """
    doc_ids = list(doc_ids)
    N = len(doc_ids)

    # 1) Precompute candidate sets per query
    cache = {}  # qid -> dict with candidate indices + normalized scores per norm
    for qid, qtext in queries_int.items():
        d_raw = np.asarray(dense._get_scores(qtext))
        b_raw = np.asarray(bm25.get_scores(tokenize(qtext)))

        # topM from each retriever
        d_top = np.argsort(d_raw)[::-1][:pre_topM]
        b_top = np.argsort(b_raw)[::-1][:pre_topM]

        cand_idx = np.unique(np.concatenate([d_top, b_top]))
        d_cand = d_raw[cand_idx]
        b_cand = b_raw[cand_idx]

        # normalize PER QUERY but only on candidate set (fast + consistent for sweep)
        normed = {}
        for norm in norm_methods:
            normed[norm] = {
                "d": normalize_scores(d_cand, norm),
                "b": normalize_scores(b_cand, norm),
            }

        cache[qid] = {
            "cand_idx": cand_idx,
            "normed": normed,
        }

    # 2) Sweep cheaply
    rows = []
    for norm in norm_methods:
        for fusion in fusion_methods:
            for alpha in alphas:
                for k in ks:
                    hits = []
                    mrrs = []

                    for qid in queries_int.keys():
                        cand_idx = cache[qid]["cand_idx"]
                        d_norm = cache[qid]["normed"][norm]["d"]
                        b_norm = cache[qid]["normed"][norm]["b"]

                        fused = fuse_scores(d_norm, b_norm, fusion, alpha)

                        # rank within candidates only
                        top_local = np.argsort(fused)[::-1][:k]
                        top_global = cand_idx[top_local]
                        top_doc_ids = [doc_ids[i] for i in top_global]

                        qrel = qrels_int.get(qid, {})
                        hits.append(hit_at_k(top_doc_ids, qrel))
                        mrrs.append(mrr_at_k(top_doc_ids, qrel))

                    rows.append({
                        "norm": norm,
                        "fusion": fusion,
                        "alpha": float(alpha),
                        "k": int(k),
                        "hit@k": float(np.mean(hits)),
                        "mrr@k": float(np.mean(mrrs)),
                        "pre_topM": int(pre_topM),
                    })

    return pd.DataFrame(rows)

# %%
results_df = fast_sweep_fusion(
    queries_int=queries_int,
    qrels_int=qrels_int,
    dense=dense,
    bm25=bm25,
    doc_ids=doc_ids,
    tokenize=tokenize,
    norm_methods=("rank",),          # start with 1 norm
    fusion_methods=("wsum",),        # start with 1 fusion
    alphas=np.linspace(0, 1, 11),    # 11 alphas
    ks=(1, 3, 5, 10, 20, 50),
    pre_topM=200                     # union of top200 from each retriever
)

results_df.sort_values(["k", "hit@k"], ascending=[True, False])

# %%
dense_baseline = {1:0.503, 3:0.683, 5:0.753, 10:0.793, 20:0.847, 50:0.900}
bm25_baseline  = {1:0.523, 3:0.693, 5:0.757, 10:0.797, 20:0.850, 50:0.873}

# %%
import matplotlib.pyplot as plt

for k in sorted(results_df["k"].unique()):
    sub = results_df[results_df["k"] == k].sort_values("alpha")

    plt.figure(figsize=(8,5))
    plt.plot(sub["alpha"], sub["hit@k"], marker="o", label="Fusion (rank+wsum)")
    plt.axhline(dense_baseline[k], linestyle="--", label="Dense baseline")
    plt.axhline(bm25_baseline[k], linestyle=":", label="BM25 baseline")

    plt.title(f"Fusion vs alpha at k={k}")
    plt.xlabel("alpha (dense weight)")
    plt.ylabel("hit@k")
    plt.ylim(0, 1)
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
best_fusion = results_df.loc[results_df.groupby("k")["hit@k"].idxmax()].sort_values("k")

plt.figure(figsize=(8,5))
plt.plot(best_fusion["k"], best_fusion["hit@k"], marker="o", label="Best fusion (over alpha)")
plt.plot(list(dense_baseline.keys()), list(dense_baseline.values()), marker="o", linestyle="--", label="Dense")
plt.plot(list(bm25_baseline.keys()), list(bm25_baseline.values()), marker="o", linestyle=":", label="BM25")

plt.title("Best fusion vs Dense vs BM25")
plt.xlabel("k")
plt.ylabel("hit@k")
plt.ylim(0, 1)
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

display(best_fusion)

# %%
import numpy as np

pivot = results_df.pivot_table(index="alpha", columns="k", values="hit@k")
plt.figure(figsize=(7,5))
plt.imshow(pivot.values, aspect="auto", origin="lower")
plt.xticks(ticks=np.arange(len(pivot.columns)), labels=pivot.columns)
plt.yticks(ticks=np.arange(len(pivot.index)), labels=[f"{a:.1f}" for a in pivot.index])
plt.xlabel("k")
plt.ylabel("alpha")
plt.title("Fusion hit@k heatmap (rank+wsum)")
plt.colorbar(label="hit@k")
plt.show()

# %%
# week 6 summarized in one code cell
# =========================
# Week 6: Pricing + Hybrid Pricing (Dense + BM25)
# End-to-end notebook code (SciFact / BEIR)
# =========================

import os
import json
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from rank_bm25 import BM25Okapi

# ---- your project imports (adjust if needed) ----
import cg_rag.data.beir_loader as BL
import cg_rag.core.segment as S
import cg_rag.models.embedding as E
import cg_rag.baselines.retrievers as R


# =========================
# 0) Helpers
# =========================

def is_hit_at_k(retrieved_doc_ids, qrel_dict):
    gold = set(qrel_dict.keys())
    return any(d in gold for d in retrieved_doc_ids)

def rank_norm(x):
    order = np.argsort(x)
    ranks = np.empty_like(order, dtype=float)
    ranks[order] = np.arange(len(x), dtype=float)
    return ranks / max(len(x) - 1, 1)

token_pat = re.compile(r"\w+")
def tokenize(text: str):
    return token_pat.findall(text.lower())

def ensure_dir(p):
    os.makedirs(p, exist_ok=True)

CACHE_DIR = "./cache_week6_scifact"
ensure_dir(CACHE_DIR)


# =========================
# 1) Load BEIR SciFact
# =========================

dataset = BL.load_beir_dataset("scifact")

# These are dict-like in your existing notebook flow
corpus = dataset.documents   # doc_id -> {title,text,...} or similar object
queries = dataset.queries    # qid -> query string
qrels  = dataset.qrels       # qid -> {doc_id: rel, ...}

print("Docs:", len(corpus))
print("Queries:", len(queries))
print("Qrels:", len(qrels))


# =========================
# 2) Build doc_texts and aligned doc id list
#    IMPORTANT: decide the order ONCE and stick to it
# =========================

# Use the corpus keys order consistently (SciFact is small so OK).
# If you already have segment_doc_ids from earlier, replace doc_ids with that list.
doc_ids = list(corpus.keys())

doc_texts = [
    (corpus[doc_id].get("title","") + " " + corpus[doc_id].get("text","")).strip()
    for doc_id in doc_ids
]

print("doc_texts:", len(doc_texts))


# =========================
# 3) Embeddings (cached)
# =========================

VEC_PATH = os.path.join(CACHE_DIR, "doc_vectors.npy")
DOCID_PATH = os.path.join(CACHE_DIR, "doc_ids.json")

# Choose the same embedder/model you've been using.
# Replace with Qwen embed model name if you want, but CPU is fine for SciFact.
MODEL_NAME = "BAAI/bge-base-en-v1.5"

if os.path.exists(VEC_PATH) and os.path.exists(DOCID_PATH):
    print("Loading cached embeddings:", VEC_PATH)
    doc_vectors = np.load(VEC_PATH)
    with open(DOCID_PATH, "r") as f:
        cached_doc_ids = json.load(f)
    assert cached_doc_ids == doc_ids, "Cached doc_id order mismatch. Delete cache_week6_scifact and rerun."
else:
    print("Computing embeddings (cached after)...")
    embedder = E.Embedder(model_name=MODEL_NAME)
    doc_vectors = embedder.embed(doc_texts, show_progress=True)
    np.save(VEC_PATH, doc_vectors)
    with open(DOCID_PATH, "w") as f:
        json.dump(doc_ids, f)
    print("Saved:", VEC_PATH)

print("doc_vectors:", doc_vectors.shape)


# =========================
# 4) Build segments + mapping like your notebook
# =========================

segments = []
segment_doc_ids = []  # aligned with segments index

for i, doc_id in enumerate(doc_ids):
    segments.append(
        S.Segment(
            segment_id=i,
            doc_id=doc_id,
            text=doc_texts[i],
            vector=doc_vectors[i],
        )
    )
    segment_doc_ids.append(doc_id)

# seg_id_to_idx so you can map result.segments -> doc_ids (like your code)
seg_id_to_idx = {id(seg): i for i, seg in enumerate(segments)}

print("segments:", len(segments))


# =========================
# 5) Dense baseline (top_k=50, hit@10)
# =========================

embedder = E.Embedder(model_name=MODEL_NAME)
dense = R.DenseRetriever(segments=segments, embedder=embedder, top_k=50)

dense_hits = []
dense_fail_qids = []

for qid, qtext in queries.items():
    result = dense.retrieve(qtext)  # RetrievalResult

    retrieved_doc_ids = []
    for seg in result.segments[:10]:
        idx = seg_id_to_idx[id(seg)]
        retrieved_doc_ids.append(segment_doc_ids[idx])

    hit = is_hit_at_k(retrieved_doc_ids, qrels.get(qid, {}))
    dense_hits.append(hit)
    if not hit:
        dense_fail_qids.append(qid)

dense_h10 = sum(dense_hits) / len(dense_hits)
print(f"Dense hit@10: {sum(dense_hits)}/{len(dense_hits)} = {dense_h10:.3f}")
print("Dense failures:", len(dense_fail_qids))


# =========================
# 6) BM25 baseline (ALIGNED to segment_doc_ids order)
# =========================

doc_texts_aligned = [
    (corpus[doc_id].get("title","") + " " + corpus[doc_id].get("text","")).strip()
    for doc_id in segment_doc_ids
]
bm25 = BM25Okapi([tokenize(t) for t in doc_texts_aligned])

# sanity check
qid0 = next(iter(queries.keys()))
b0 = bm25.get_scores(tokenize(queries[qid0]))
print("BM25 check:", b0.shape, b0.min(), b0.max())

bm25_hits = []
bm25_fail_qids = []

for qid, qtext in queries.items():
    b = bm25.get_scores(tokenize(qtext))
    top_idx = np.argsort(b)[::-1][:10]
    retrieved_doc_ids = [segment_doc_ids[i] for i in top_idx]

    hit = is_hit_at_k(retrieved_doc_ids, qrels.get(qid, {}))
    bm25_hits.append(hit)
    if not hit:
        bm25_fail_qids.append(qid)

bm25_h10 = sum(bm25_hits) / len(bm25_hits)
print(f"BM25 hit@10: {sum(bm25_hits)}/{len(bm25_hits)} = {bm25_h10:.3f}")
print("BM25 failures:", len(bm25_fail_qids))


# =========================
# 7) Dense pricing + Hybrid pricing
# =========================

def dense_pricing_indices(query, lam_d=1.0, cost=1.0, k=10):
    d = dense._get_scores(query)
    dN = rank_norm(d)
    rc = cost - lam_d * dN

    selected = np.where(rc < 0)[0]
    if len(selected) == 0:
        selected = np.argsort(dN)[::-1][:k]
    else:
        selected = selected[np.argsort(dN[selected])[::-1]]
    return selected

def hybrid_pricing_indices(query, lam_d=1.0, lam_s=1.0, cost=1.0, k=10):
    d = dense._get_scores(query)
    b = bm25.get_scores(tokenize(query))

    dN = rank_norm(d)
    bN = rank_norm(b)

    rc = cost - lam_d*dN - lam_s*bN
    fused = lam_d*dN + lam_s*bN

    selected = np.where(rc < 0)[0]
    if len(selected) == 0:
        selected = np.argsort(fused)[::-1][:k]
    else:
        selected = selected[np.argsort(fused[selected])[::-1]]
    return selected

def eval_indices_fn(get_idx_fn, k=10):
    hits = 0
    for qid, qtext in queries.items():
        idx = get_idx_fn(qtext, k=k)
        retrieved_doc_ids = [segment_doc_ids[i] for i in idx[:k]]
        if is_hit_at_k(retrieved_doc_ids, qrels.get(qid, {})):
            hits += 1
    return hits / len(queries)

dense_pricing_h10 = eval_indices_fn(lambda q, k: dense_pricing_indices(q, lam_d=1.0, k=k), k=10)
hybrid_pricing_h10 = eval_indices_fn(lambda q, k: hybrid_pricing_indices(q, lam_d=1.0, lam_s=1.0, k=k), k=10)

print("Dense pricing hit@10:", round(dense_pricing_h10, 3))
print("Hybrid pricing hit@10:", round(hybrid_pricing_h10, 3))


# =========================
# 8) Lambda sweep (small grid)
# =========================

grid = []
for lam_d in [0.5, 1.0, 2.0]:
    for lam_s in [0.5, 1.0, 2.0]:
        h10 = eval_indices_fn(lambda q, k: hybrid_pricing_indices(q, lam_d=lam_d, lam_s=lam_s, k=k), k=10)
        grid.append({"lam_d": lam_d, "lam_s": lam_s, "hit10": h10})

grid_df = pd.DataFrame(grid).sort_values("hit10", ascending=False)
display(grid_df.head(10))


# =========================
# 9) Simple plot (baseline comparison)
# =========================

labels = ["Dense", "BM25", "Dense pricing", "Hybrid pricing"]
vals   = [dense_h10, bm25_h10, dense_pricing_h10, hybrid_pricing_h10]

plt.figure()
plt.bar(labels, vals)
plt.ylim(0, 1.0)
plt.ylabel("Hit@10")
plt.title("Week 6: Pricing + Hybrid Pricing (SciFact)")
plt.xticks(rotation=20, ha="right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 17
#      14 from rank_bm25 import BM25Okapi
#      16 # ---- your project imports (adjust if needed) ----
# ---> 17 import cg_rag.data.beir_loader as BL
#      18 import cg_rag.core.segment as S
#      19 import cg_rag.models.embedding as E
#
# ModuleNotFoundError: No module named 'cg_rag.data'

# %%
# ============================================================
# Week 6 (Clean Notebook): SciFact (BEIR) + Dense + BM25 + Pricing
# Uses cg_rag DenseRetriever / Embedder / Segment, and rank_bm25
# ============================================================

# ----------------------------
# 0) Imports
# ----------------------------
import os
import re
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from beir import util
from beir.datasets.data_loader import GenericDataLoader
from rank_bm25 import BM25Okapi

import cg_rag.baselines.retrievers as R
import cg_rag.models.embedding as E
import cg_rag.structures as S  # contains Segment, RetrievalResult, etc.


# ----------------------------
# 1) Download + load SciFact (BEIR)
# ----------------------------
DATA_DIR = "./datasets"
os.makedirs(DATA_DIR, exist_ok=True)

data_path = util.download_and_unzip(
    "https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/scifact.zip",
    DATA_DIR
)

corpus, queries, qrels = GenericDataLoader(data_path).load(split="test")

print("Num documents:", len(corpus))
print("Num queries:", len(queries))
print("Num qrels:", len(qrels))


# ----------------------------
# 2) Build aligned doc_ids + doc_texts (order is fixed!)
# ----------------------------
doc_ids = list(corpus.keys())
doc_texts = [
    (corpus[doc_id].get("title", "") + " " + corpus[doc_id].get("text", "")).strip()
    for doc_id in doc_ids
]

print("Example doc:", doc_ids[0], doc_texts[0][:200])


# ----------------------------
# 3) (Optional) Cache embeddings so you don't recompute
# ----------------------------
CACHE_DIR = "./cache_week6_scifact"
os.makedirs(CACHE_DIR, exist_ok=True)

VEC_PATH = os.path.join(CACHE_DIR, "doc_vectors.npy")
DOCID_PATH = os.path.join(CACHE_DIR, "doc_ids.json")

# cg_rag Embedder chooses GPU if available; CPU otherwise
embedder = E.Embedder()  # uses your repo defaults

if os.path.exists(VEC_PATH) and os.path.exists(DOCID_PATH):
    with open(DOCID_PATH, "r") as f:
        cached_doc_ids = json.load(f)
    if cached_doc_ids != doc_ids:
        raise ValueError(
            "Cached doc_ids order mismatch. Delete ./cache_week6_scifact and rerun."
        )
    doc_vectors = np.load(VEC_PATH)
    print("Loaded cached embeddings:", doc_vectors.shape)
else:
    print("Computing embeddings...")
    doc_vectors = embedder.embed(doc_texts, show_progress=True)
    np.save(VEC_PATH, doc_vectors)
    with open(DOCID_PATH, "w") as f:
        json.dump(doc_ids, f)
    print("Saved embeddings:", doc_vectors.shape)


# ----------------------------
# 4) Build Segments in the SAME order as doc_ids/doc_texts/doc_vectors
#    (this makes everything align by index)
# ----------------------------
segments = []
segment_doc_ids = []

for i, doc_id in enumerate(doc_ids):
    # Segment signature in your repo: (text, vector, start_idx, end_idx, sentences, internal_cost)
    segments.append(
        S.Segment(
            text=doc_texts[i],
            vector=doc_vectors[i],
            start_idx=0,
            end_idx=len(doc_texts[i]),
            sentences=[],
            internal_cost=1.0,
        )
    )
    segment_doc_ids.append(doc_id)

# map python object id -> index, so you can map DenseRetriever outputs back to doc_ids
seg_id_to_idx = {id(seg): i for i, seg in enumerate(segments)}

print("Segments:", len(segments))


# ----------------------------
# 5) Dense baseline (hit@10)
# ----------------------------
dense = R.DenseRetriever(segments=segments, embedder=embedder, top_k=50)

def is_hit_at_k(retrieved_doc_ids, qrel_dict):
    gold = set(qrel_dict.keys())
    return any(d in gold for d in retrieved_doc_ids)

dense_hits = []
dense_fail_qids = []

for qid, qtext in queries.items():
    result = dense.retrieve(qtext)

    retrieved_doc_ids = [
        segment_doc_ids[seg_id_to_idx[id(s)]]
        for s in result.segments[:10]
    ]

    hit = is_hit_at_k(retrieved_doc_ids, qrels.get(qid, {}))
    dense_hits.append(hit)
    if not hit:
        dense_fail_qids.append(qid)

dense_h10 = sum(dense_hits) / len(dense_hits)
print(f"Dense hit@10: {sum(dense_hits)}/{len(dense_hits)} = {dense_h10:.3f}")
print("Dense failures:", len(dense_fail_qids))


# ----------------------------
# 6) BM25 baseline (MUST be aligned to segment_doc_ids order)
# ----------------------------
token_pat = re.compile(r"\w+")
def tokenize(text: str):
    return token_pat.findall(text.lower())

bm25 = BM25Okapi([tokenize(t) for t in doc_texts])  # doc_texts is aligned with segments/doc_ids

# sanity check
qid0 = next(iter(queries.keys()))
b0 = bm25.get_scores(tokenize(queries[qid0]))
print("BM25 check:", b0.shape, b0.min(), b0.max())

bm25_hits = []
bm25_fail_qids = []

for qid, qtext in queries.items():
    b = bm25.get_scores(tokenize(qtext))
    top_idx = np.argsort(b)[::-1][:10]
    retrieved_doc_ids = [segment_doc_ids[i] for i in top_idx]

    hit = is_hit_at_k(retrieved_doc_ids, qrels.get(qid, {}))
    bm25_hits.append(hit)
    if not hit:
        bm25_fail_qids.append(qid)

bm25_h10 = sum(bm25_hits) / len(bm25_hits)
print(f"BM25 hit@10: {sum(bm25_hits)}/{len(bm25_hits)} = {bm25_h10:.3f}")
print("BM25 failures:", len(bm25_fail_qids))


# ----------------------------
# 7) Pricing methods (Week 6)
# ----------------------------
def rank_norm(x):
    order = np.argsort(x)
    ranks = np.empty_like(order, dtype=float)
    ranks[order] = np.arange(len(x), dtype=float)
    return ranks / max(len(x) - 1, 1)

def dense_pricing_indices(query, lam_d=1.0, cost=1.0, k=10):
    d = dense._get_scores(query)
    dN = rank_norm(d)
    rc = cost - lam_d * dN

    selected = np.where(rc < 0)[0]
    if len(selected) == 0:
        selected = np.argsort(dN)[::-1][:k]
    else:
        selected = selected[np.argsort(dN[selected])[::-1]]
    return selected

def hybrid_pricing_indices(query, lam_d=1.0, lam_s=1.0, cost=1.0, k=10):
    d = dense._get_scores(query)
    b = bm25.get_scores(tokenize(query))

    dN = rank_norm(d)
    bN = rank_norm(b)

    rc = cost - lam_d*dN - lam_s*bN
    fused = lam_d*dN + lam_s*bN

    selected = np.where(rc < 0)[0]
    if len(selected) == 0:
        selected = np.argsort(fused)[::-1][:k]
    else:
        selected = selected[np.argsort(fused[selected])[::-1]]
    return selected

def eval_indices_fn(get_idx_fn, k=10):
    hits = 0
    for qid, qtext in queries.items():
        idx = get_idx_fn(qtext, k=k)
        retrieved_doc_ids = [segment_doc_ids[i] for i in idx[:k]]
        if is_hit_at_k(retrieved_doc_ids, qrels.get(qid, {})):
            hits += 1
    return hits / len(queries)

dense_pricing_h10 = eval_indices_fn(lambda q, k: dense_pricing_indices(q, lam_d=1.0, k=k), k=10)
hybrid_pricing_h10 = eval_indices_fn(lambda q, k: hybrid_pricing_indices(q, lam_d=1.0, lam_s=1.0, k=k), k=10)

print("Dense pricing hit@10:", round(dense_pricing_h10, 3))
print("Hybrid pricing hit@10:", round(hybrid_pricing_h10, 3))


# ----------------------------
# 8) Small lambda sweep (optional but great for Week 6 writeup)
# ----------------------------
grid = []
for lam_d in [0.5, 1.0, 2.0]:
    for lam_s in [0.5, 1.0, 2.0]:
        h10 = eval_indices_fn(lambda q, k: hybrid_pricing_indices(q, lam_d=lam_d, lam_s=lam_s, k=k), k=10)
        grid.append({"lam_d": lam_d, "lam_s": lam_s, "hit10": h10})

grid_df = pd.DataFrame(grid).sort_values("hit10", ascending=False)
display(grid_df.head(10))


# ----------------------------
# 9) Plot summary
# ----------------------------
labels = ["Dense", "BM25", "Dense pricing", "Hybrid pricing"]
vals   = [dense_h10, bm25_h10, dense_pricing_h10, hybrid_pricing_h10]

plt.figure()
plt.bar(labels, vals)
plt.ylim(0, 1.0)
plt.ylabel("Hit@10")
plt.title("Week 6: Pricing + Hybrid Pricing (SciFact)")
plt.xticks(rotation=20, ha="right")
plt.show()

def hybrid_pricing_AND_indices(query, lam_d=1.0, lam_s=1.0, cost=1.0, k=10):

    # dense scores
    d = dense._get_scores(query)

    # sparse scores
    b = bm25.get_scores(tokenize(query))

    # normalize
    dN = rank_norm(d)
    bN = rank_norm(b)

    # separate reduced costs
    rc_d = cost - lam_d * dN
    rc_s = cost - lam_s * bN

    # AND gating (this is the key Week 6 experiment)
    selected = np.where((rc_d < 0) & (rc_s < 0))[0]

    # fused score used only for ranking selected candidates
    fused = lam_d*dN + lam_s*bN

    if len(selected) == 0:
        selected = np.argsort(fused)[::-1][:k]
    else:
        selected = selected[np.argsort(fused[selected])[::-1]]

    return selected
hybrid_AND_h10 = eval_indices_fn(
    lambda q, k: hybrid_pricing_AND_indices(q, lam_d=1.0, lam_s=1.0, k=k),
    k=10
)

print("Hybrid pricing (AND) hit@10:", round(hybrid_AND_h10, 3))
# Out:
#   0%|          | 0/5183 [00:00<?, ?it/s]
# Num documents: 5183
# Num queries: 300
# Num qrels: 300
# Example doc: 4983 Microstructural development of human newborn cerebral white matter assessed in vivo by diffusion tensor magnetic resonance imaging. Alterations of the architecture of cerebral white matter in the deve
# No GPU found. Using lightweight CPU embedder: all-MiniLM-L6-v2
# Loading embedding model: None
# Embedder ready (dim=384)
# Loaded cached embeddings: (5183, 384)
# Segments: 5183
# Dense hit@10: 238/300 = 0.793
# Dense failures: 62
# BM25 check: (5183,) 0.0 10.173663486906072
# BM25 hit@10: 239/300 = 0.797
# BM25 failures: 61
# Dense pricing hit@10: 0.793
# Hybrid pricing hit@10: 0.82
#    lam_d  lam_s     hit10
# 0    0.5    0.5  0.820000
# 4    1.0    1.0  0.820000
# 8    2.0    2.0  0.820000
# 1    0.5    1.0  0.813333
# 2    0.5    2.0  0.813333
# 5    1.0    2.0  0.813333
# 3    1.0    0.5  0.810000
# 6    2.0    0.5  0.810000
# 7    2.0    1.0  0.810000
# ...

# %%
# ============================================================
# Week 6 add-on: "Sparse features in U" via TF-IDF channel
# (Copy-paste into ONE new cell and run)
#
# Assumes these already exist in your notebook:
#   - dense : R.DenseRetriever
#   - bm25  : BM25Okapi (optional; only used for comparison if present)
#   - tokenize(text) -> List[str]
#   - rank_norm(x) -> np.ndarray
#   - is_hit_at_k(retrieved_doc_ids, qrel_dict) -> bool
#   - queries : dict[qid -> query str]
#   - qrels   : dict[qid -> {doc_id: rel, ...}]
#   - segment_doc_ids : list where segment_doc_ids[i] is doc_id for doc/segment i
#   - doc_texts_aligned OR doc_texts : list of doc texts aligned with segment_doc_ids
#
# Output:
#   - TF-IDF baseline hit@10
#   - Hybrid pricing using TF-IDF sparse scores hit@10
#   - (Optional) Hybrid pricing using BM25 sparse scores hit@10 (if bm25 exists)
# ============================================================

import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# ----------------------------
# 0) Choose the aligned document texts
# ----------------------------
# Prefer doc_texts_aligned if you created it; otherwise use doc_texts (must be aligned!)
try:
    _DOC_TEXTS = doc_texts_aligned
except NameError:
    _DOC_TEXTS = doc_texts

assert len(_DOC_TEXTS) == len(segment_doc_ids), (
    f"Alignment error: len(doc_texts)= {len(_DOC_TEXTS)} vs len(segment_doc_ids)= {len(segment_doc_ids)}"
)

print("TF-IDF docs:", len(_DOC_TEXTS))

# ----------------------------
# 1) Build TF-IDF doc matrix (this is your sparse 'U' channel)
# ----------------------------
# NOTE: these params are reasonable defaults for SciFact; tweak later if you want.
tfidf = TfidfVectorizer(
    tokenizer=tokenize,          # reuse your tokenizer for consistent term defs
    lowercase=True,
    ngram_range=(1, 2),
    min_df=2,
    max_df=0.95,
)

U_sparse = tfidf.fit_transform(_DOC_TEXTS)  # shape: (N_docs, V)
print("U_sparse shape:", U_sparse.shape)

def tfidf_scores(query: str) -> np.ndarray:
    """Return TF-IDF relevance scores aligned with segment_doc_ids index."""
    q_vec = tfidf.transform([query])              # (1, V)
    s = (U_sparse @ q_vec.T).toarray().ravel()    # (N_docs,)
    return s

# ----------------------------
# 2) TF-IDF baseline (rank by TF-IDF only)
# ----------------------------
def eval_tfidf_baseline(k=10):
    hits = 0
    for qid, qtext in queries.items():
        s = tfidf_scores(qtext)
        top_idx = np.argsort(s)[::-1][:k]
        retrieved_doc_ids = [segment_doc_ids[i] for i in top_idx]
        if is_hit_at_k(retrieved_doc_ids, qrels.get(qid, {})):
            hits += 1
    return hits / len(queries)

tfidf_h10 = eval_tfidf_baseline(k=10)
print("TF-IDF baseline hit@10:", round(tfidf_h10, 3))

# ----------------------------
# 3) Hybrid pricing using TF-IDF as the sparse term
#    rc = cost - lam_d*dN - lam_s*sN
# ----------------------------
def hybrid_pricing_tfidf_indices(query, lam_d=1.0, lam_s=1.0, cost=1.0, k=10):
    d = dense._get_scores(query)        # dense scores (aligned)
    s = tfidf_scores(query)             # tf-idf scores (aligned)

    dN = rank_norm(d)
    sN = rank_norm(s)

    rc = cost - lam_d*dN - lam_s*sN
    fused = lam_d*dN + lam_s*sN

    selected = np.where(rc < 0)[0]
    if len(selected) == 0:
        selected = np.argsort(fused)[::-1][:k]
    else:
        selected = selected[np.argsort(fused[selected])[::-1]]
    return selected

def eval_hybrid_pricing_tfidf(lam_d=1.0, lam_s=1.0, k=10):
    hits = 0
    for qid, qtext in queries.items():
        idx = hybrid_pricing_tfidf_indices(qtext, lam_d=lam_d, lam_s=lam_s, k=k)
        retrieved_doc_ids = [segment_doc_ids[i] for i in idx[:k]]
        if is_hit_at_k(retrieved_doc_ids, qrels.get(qid, {})):
            hits += 1
    return hits / len(queries)

hybrid_tfidf_h10 = eval_hybrid_pricing_tfidf(lam_d=1.0, lam_s=1.0, k=10)
print("Hybrid pricing (TF-IDF) hit@10:", round(hybrid_tfidf_h10, 3))

# ----------------------------
# 4) Optional: compare against BM25 hybrid pricing if bm25 exists
# ----------------------------
def hybrid_pricing_bm25_indices(query, lam_d=1.0, lam_s=1.0, cost=1.0, k=10):
    d = dense._get_scores(query)
    b = bm25.get_scores(tokenize(query))

    dN = rank_norm(d)
    bN = rank_norm(b)

    rc = cost - lam_d*dN - lam_s*bN
    fused = lam_d*dN + lam_s*bN

    selected = np.where(rc < 0)[0]
    if len(selected) == 0:
        selected = np.argsort(fused)[::-1][:k]
    else:
        selected = selected[np.argsort(fused[selected])[::-1]]
    return selected

def eval_hybrid_pricing_bm25(lam_d=1.0, lam_s=1.0, k=10):
    hits = 0
    for qid, qtext in queries.items():
        idx = hybrid_pricing_bm25_indices(qtext, lam_d=lam_d, lam_s=lam_s, k=k)
        retrieved_doc_ids = [segment_doc_ids[i] for i in idx[:k]]
        if is_hit_at_k(retrieved_doc_ids, qrels.get(qid, {})):
            hits += 1
    return hits / len(queries)

try:
    _ = bm25  # existence check
    hybrid_bm25_h10 = eval_hybrid_pricing_bm25(lam_d=1.0, lam_s=1.0, k=10)
    print("Hybrid pricing (BM25) hit@10:", round(hybrid_bm25_h10, 3))
except NameError:
    print("BM25 not found in notebook; skipping BM25 hybrid pricing comparison.")

# ----------------------------
# 5) Small lambda sweep for TF-IDF hybrid pricing (optional but useful)
# ----------------------------
grid = []
for lam_d in [0.5, 1.0, 2.0]:
    for lam_s in [0.5, 1.0, 2.0]:
        h10 = eval_hybrid_pricing_tfidf(lam_d=lam_d, lam_s=lam_s, k=10)
        grid.append((lam_d, lam_s, h10))

grid_sorted = sorted(grid, key=lambda x: x[2], reverse=True)
print("\nTop TF-IDF hybrid pricing settings (lam_d, lam_s, hit@10):")
for row in grid_sorted[:5]:
    print(row)
# Out:
# TF-IDF docs: 5183
# /Users/Tyler/.local/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# U_sparse shape: (5183, 119742)
# TF-IDF baseline hit@10: 0.723
# Hybrid pricing (TF-IDF) hit@10: 0.813
# Hybrid pricing (BM25) hit@10: 0.82
#
# Top TF-IDF hybrid pricing settings (lam_d, lam_s, hit@10):
# (0.5, 0.5, 0.8133333333333334)
# (0.5, 1.0, 0.8133333333333334)
# (1.0, 1.0, 0.8133333333333334)
# (1.0, 2.0, 0.8133333333333334)
# (2.0, 2.0, 0.8133333333333334)
